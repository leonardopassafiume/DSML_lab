# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    "iris.csv",
    header=None
)

# %%
# shuffle of the rows of the df
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

#define the split index
split_index = int(0.8 * len(df))

# split the data
train_df = df.iloc[:split_index]
test_df = df.iloc[split_index:]

X_test = test_df.iloc[:, :-1]
y_test = test_df.iloc[:, -1]
X_train = train_df.iloc[:, :-1]
y_train = train_df.iloc[:, -1]

# %%
class KNearestNeighbours:
    def __init__ (self, k, distance_metric = "euclidean"):
        self.k = k
        self.distance_metric = distance_metric
        self.X_train = None
        self.Y_train = None

    def fit(self, X, y):
        self.X_train = X 
        self.y_train = y
    

    def euclidean_mio(self, A, B): 
        dist_matrix = np.zeros((len(A),len(B)))
        for i in range(0,len(A)):
            for j in range(0,len(B)):
                dist_matrix[i,j] = np.sqrt(np.sum((A.iloc[i,:] - B.iloc[j,:])**2))
        
        return dist_matrix

        
    def euclidean(self, A, B):
        A = A.to_numpy()
        B = B.to_numpy()
            
        dist_matrix = np.sqrt(((A[:, np.newaxis, :] - B[np.newaxis, :, :]) ** 2).sum(axis=2))
        return dist_matrix


  #  def _cosine(self, A, B):
 #       dist = 1 - np.abs(np.dot(A, B)/(np.linalg.norm(A) * np.linalg.norm(B)))
  #  return dist
    

   # def _manhattan(self, p, q):
     #   dist = np.sum(np.abs(A - B))
    #return dist
    
    
    def predict(self, X):
        """Run the KNN classification on X.
        :param X: input data points, ndarray, shape = (N, C).
        :return: labels: ndarray, shape = (N,).
        """
        return X.iloc[0]  # TODO: implement it!

# %%
A = X_train
B = X_test
A.iloc[0,:]
dist_matrix = np.zeros((len(A),len(B)))
for i in range(0,len(A)):
    for j in range(0,len(B)):
        dist_matrix[i,j] = np.sqrt(np.sum((A.iloc[i,:] - B.iloc[j,:])**2))


pd.DataFrame(dist_matrix)
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.300000  3.896152  0.529150  0.700000  3.562303  0.812404  2.090454
# 1    3.228002  1.962142  3.321144  3.095158  0.469042  2.722132  5.174940
# 2    2.969848  6.759438  2.754995  3.507136  6.367103  3.661967  0.927362
# 3    0.200000  3.780212  0.640312  0.663325  3.438023  0.608276  2.240536
# 4    0.754983  4.358899  0.316228  1.389244  3.923009  1.407125  1.634013
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  1.334166  5.142956  1.187434  2.004994  4.662617  2.007486  1.048809
# 116  0.458258  3.507136  0.836660  0.670820  3.135283  0.374166  2.543619
# 117  0.938083  4.752894  0.932738  1.562050  4.342810  1.584298  1.378405
# 118  1.300000  2.619160  1.483240  0.943398  2.451530  0.787401  3.336165
# 119  1.178983  2.935984  1.581139  0.624500  2.865310  0.547723  3.220248
#
#            7         8         9   ...        20        21        22  \
# 0    1.555635  3.562303  1.897367  ...  0.624500  0.519615  0.964365
# 1    4.526588  0.648074  2.376973  ...  3.301515  3.009983  3.760319
# 2    1.723369  6.382789  4.746578  ...  3.049590  3.088689  2.922328
# 3    1.565248  3.414674  1.774824  ...  0.707107  0.489898  0.761577
# 4    1.249000  3.948417  2.485961  ...  0.818535  0.655744  1.345362
# ..        ...       ...       ...  ...       ...       ...       ...
# 115  0.412311  4.658326  3.179623  ...  1.624808  1.462874  1.428286
# 116  1.827567  3.103224  1.555635  ...  0.854400  0.556776  0.932738
# 117  0.624500  4.324350  2.744085  ...  1.288410  1.148913  0.969536
# 118  2.745906  2.435159  0.848528  ...  1.161895  1.144552  1.734935
# 119  2.517936  2.787472  0.836660  ...  1.276715  1.284523  1.236932
#
#            23        24        25        26        27        28        29
# 0    0.774597  3.293934  0.707107  1.349074  3.844477  0.787401  1.813836
# 1    3.806573  0.509902  2.729469  3.482815  0.556776  2.747726  4.845617
# 2    2.624881  6.113919  3.465545  3.737646  6.516901  3.637307  1.249000
# 3    0.685565  3.184337  0.556776  1.187434  3.718871  0.685565  1.881489
# 4    1.048809  3.656501  1.067708  1.969772  4.103657  1.311488  1.352775
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  1.090871  4.431704  1.824829  2.308679  4.823899  2.056696  0.547723
# 116  0.948683  2.889637  0.400000  1.174734  3.420526  0.547723  2.165641
# 117  0.640312  4.106093  1.459452  1.841195  4.553021  1.652271  0.927362
# 118  1.843909  2.147091  0.734847  1.462874  2.810694  0.547723  3.014963
# 119  1.476482  2.609598  0.916515  0.761577  3.283291  0.648074  2.861818
#
# [120 rows x 30 columns]
